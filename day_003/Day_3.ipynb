# %%
# age height and complex number info
age = int(19)
height = float(6.5)
complex_number = complex(2 + 8j)
print('The Age is: ', age, 'yers old')
print('The height is: ', height, 'm', sep='')
print('The stored complex number is: ', complex_number)
# Out:
# The Age is:  19 yers old
# The height is: 6.5m
# The stored complex number is:  (2+8j)

# %%
# area of triangle
print('Do you want to find the area of triangle? \nwrite its base and height magnitude below')
base = float(input('write the base magnitude  of the triangle: '))
height_of_triangle = float(input('write the height magnitude  of the triangle: '))
area_of_triangle = float(format(0.5*base*height_of_triangle, '.2f'))
print('The area of triangle is: ', area_of_triangle, 'cm', sep='')
# Out:
# Do you want to find the area of triangle?
# write its base and height magnitude below
# The area of triangle is: 726.0cm

# %%
# perimeter of triangle
print('Do you want to find the perimeter of triangle? \nwrite its base, leangth and height magnitude below')
side_a = float(input('write the leangh magnitude of the triangle: '))
print(side_a)
side_b = float(input('write the base magnitude  of the triangle: '))
print(side_b)
side_c = float(input('write the height magnitude  of the triangle: '))
print(side_c)
perimeter_of_triangle = float(format(side_a+side_b+side_c , '.2f'))
print('The perimeter of the triangle is: ', perimeter_of_triangle, 'cm', sep='')
print()
# Out:
# Do you want to find the perimeter of triangle?
# write its base, leangth and height magnitude below
# 24.0
# 54.0
# 43.0
# The perimeter of the triangle is: 121.0cm

# %%
# area of rectangle
print('Do you want to find the area of rectangle? \nwrite its leangth and width magnitude below')
length_0f_rectangle = float(input('Write the length magnitude of rectangle: '))
print(length_0f_rectangle)
width_of_rectangle = float(input('Write the length magnitude of rectangle: '))
print(width_of_rectangle)
area_of_rectangle = float(format(length_0f_rectangle*width_of_rectangle, '.2f'))
print('The area of the rectangle is: ', area_of_rectangle)
# Out:
# Do you want to find the area of rectangle?
# write its leangth and width magnitude below
# 54.0
# 23.0
# The area of the rectangle is:  1242.0

# %%
# perimeter of rectangle
print('Do you want to find the perimeter of rectangle? \nwrite its width, leangth magnitude below')
length_0f_rectangle = float(input('Write the length magnitude of rectangle: '))
print(length_0f_rectangle)
width_of_rectangle = float(input('Write the length magnitude of rectangle: '))
print(width_of_rectangle)
perimeter_of_rectangle = float(format(2*(length_0f_rectangle+width_of_rectangle), '.2f'))
print('The perimeter of the rectangle is: ', perimeter_of_rectangle, 'cm', sep='')
# Out:
# Do you want to find the perimeter of rectangle?
# write its width, leangth magnitude below
# 33.0
# 33.0
# The perimeter of the rectangle is: 132.0cm

# %%
# getting the area of a circle
print('To calculate the area of a cicle, write the magnitude of its radius below')
radius_of_circle = float(input('write the magnitude of the radius of cicle: '))
print(radius_of_circle)
pi = float(3.142)
area_of_circle = float(format(pi*(radius_of_circle*radius_of_circle), '.2f'))
print('The area of the circle is: ', area_of_circle)
# Out:
# To calculate the area of a cicle, write the magnitude of its radius below
# 45.0
# The area of the circle is:  6362.55

# %%
# getting the circumference of a circle
print('To calculate the circumference of a cicle, write the magnitude of its radius below')
radius_of_circle = float(input('write the magnitude of the radius of cicle: '))
print(radius_of_circle)
pi = float(3.142)
circum_of_circle = float(format(2*(pi*radius_of_circle), '.2f'))
print('The circumference of the circle is: ', circum_of_circle, 'cm', sep='')
# Out:
# To calculate the circumference of a cicle, write the magnitude of its radius below
# 45.0
# The circumference of the circle is: 282.78cm

# %%
# Calculate the slope, x-intercept and y-intercept of y = 2x -2
# The point are point1=(2,2) point2=(3,4)
change_in_y = int(4 - 2)
change_in_x = int(3 - 2)
slope = float(format(change_in_y/change_in_x, '.2f'))
print('The slope in x-intercept and y-intercept of y = 2x -2 is: ', slope, 'cm', sep='')
# Out:
# The slope in x-intercept and y-intercept of y = 2x -2 is: 2.0cm

# %%
# Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
# To find Euclidean we must import "math"
change_in_y_b = int(10 - 2)
change_in_x_b = int(6 - 2)
slope_b = float(format(change_in_y_b/change_in_x_b, '.2f'))
print('The slope in x-intercept and y-intercept of y = 2x -2 is equal to slope \nwith point1(2,2) and point2(6,10): ', slope==slope_b)
# Out:
# The slope in x-intercept and y-intercept of y = 2x -2 is equal to slope
# with point1(2,2) and point2(6,10):  True

# %%
# Euclidean Distance
import math
Ecldn_dstnc = math.sqrt((change_in_x_b)**2 + (change_in_y_b)**2)
Ecldn_dstnc = float(format(Ecldn_dstnc, '.2f'))
print('The Euclidean distance is: ', Ecldn_dstnc, 'cm', sep='')
# Out:
# The Euclidean distance is: 8.94cm

# %%
# Solving Quadratic Equation
# Our equation now is y = x^2 + 6x + 9
# We can change the equation to any given equation
a = int(input("Enter the coefficients of a: "))
print('a: ', a)
b = int(input("Enter the coefficients of b: "))
print('b: ', b)
c = int(input("Enter the coefficients of c: "))
print('c: ', c)

d = b**2-4*a*c # discriminant

if d < 0:
    print ("This equation has no real solution")
elif d == 0:
    x = (-b+math.sqrt(b**2-4*a*c))/2*a
    print ("This equation has one solutions: ", x)
else:
    x1 = (-b+math.sqrt((b**2)-(4*(a*c))))/(2*a)
    x2 = (-b-math.sqrt((b**2)-(4*(a*c))))/(2*a)
    print ("This equation has two solutions: ", x1, " or", x2)
# Out:
# a:  1
# b:  6
# c:  9
# This equation has one solutions:  -3.0

# %%
# accepting data from the user to calculate his rate pay per hour
print('Your daily coding earnig Calculation:')
rate_per_hour = float(input('Enter rate per hour in dollars: '))
print('$', rate_per_hour,sep='')
hour = float(input('Enter hours: '))
print(hour, 'hours', sep='')
earning = float(format(5 * (rate_per_hour*hour), '.2f'))
print('Your weekly earning is: ','$', earning, sep='')
# Out:
# Your daily coding earnig Calculation:
# $89.0
# 2.0hours
# Your weekly earning is: $890.0

# %%
# calculating number of second of the user years
# Check how old second are you 
user_years = int(input('How old are you? '))
print('You are: ', user_years, 'years old')
seconds_c = float(format(user_years*365*24*60*60, '.2f'))
minute_c = float(format(user_years*365*24*60, '.2f'))
hour_c = float(format(user_years*365*24, '.2f'))
print('You have lived for: ', hour_c, 'hours ', ' ',minute_c, 'minutes ', ' ', seconds_c,'seconds',sep='')

# This program can be use at differents sectors, like Government, Health care, and Companies
# Out:
# You are:  21 years old
# You have lived for: 183960.0hours  11037600.0minutes  662256000.0seconds

# %%
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Out:
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625

# %%
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line

# %%
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line

# %%
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line

# %%
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Define the number of rows and columns
num_rows = 5
num_columns = 5

# Print the table header
print("Table:")
print("1", end=" ")  # The first column (exponent) is (one) 1

# Print the table header (columns 2 to 5)
for column in range(1, num_columns):
    print(column + 1, end=" ")

print()  # Move to the next line

# Generate and print the table
for row in range(1, num_rows + 1):
    print(row, end=" ")  # The first column (exponent) is the row number

    for column in range(1, num_columns):
        result = row ** column
        print(result, end=" ")

    print()  # Move to the next line
# Out:
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# 4 4 16 64 256
# 5 5 25 125 625
# Table:
# 1 2 3 4 5
# 1 1 1 1 1
# 2 2 4 8 16
# 3 3 9 27 81
# ...
